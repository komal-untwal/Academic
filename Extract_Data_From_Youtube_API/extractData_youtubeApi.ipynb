# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/komaluntwal/opt/anaconda3/envs/Virtual_workspace/lib/python3.8/site-packages (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/komaluntwal/opt/anaconda3/envs/Virtual_workspace/lib/python3.8/site-packages (from requests) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/komaluntwal/opt/anaconda3/envs/Virtual_workspace/lib/python3.8/site-packages (from requests) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/komaluntwal/opt/anaconda3/envs/Virtual_workspace/lib/python3.8/site-packages (from requests) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/komaluntwal/opt/anaconda3/envs/Virtual_workspace/lib/python3.8/site-packages (from requests) (2.0.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
#import libraries
import requests
import pandas as pd
import time

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.3.4-cp38-cp38-macosx_10_9_x86_64.whl (11.4 MB)
#      |████████████████████████████████| 11.4 MB 5.4 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/komaluntwal/opt/anaconda3/envs/Virtual_workspace/lib/python3.8/site-packages (from pandas) (2.8.2)
# Collecting numpy>=1.17.3
#   Downloading numpy-1.21.2-cp38-cp38-macosx_10_9_x86_64.whl (16.9 MB)
#      |████████████████████████████████| 16.9 MB 18.3 MB/s eta 0:00:01
# Collecting pytz>=2017.3
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 48.9 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /Users/komaluntwal/opt/anaconda3/envs/Virtual_workspace/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.21.2 pandas-1.3.4 pytz-2021.3
# Note: you may need to restart the kernel to use updated packages.

# %%
#Keys
API_KEY = "AIzaSyAAy8911FwBDdconPf3Htf473TJY8eTGow"
CHANNEL_ID = "UC65foG1n1yE1n3SF6VWCGng"

# %%
def get_video_details(video_id):

    #collecting view, like, dislike, comment counts
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']

    return view_count, like_count, dislike_count, comment_count

# %%
def get_videos(df):
    pageToken = ""
    while 1:
        url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken

        response = requests.get(url).json()
        time.sleep(1) #give it a second before starting the for loop
        for video in response['items']:
            if video['id']['kind'] == "youtube#video":
                video_id = video['id']['videoId']
                video_title = video['snippet']['title']
                video_title = str(video_title).replace("&amp;","")
                upload_date = video['snippet']['publishedAt']
                upload_date = str(upload_date).split("T")[0]
                view_count, like_count, dislike_count, comment_count = get_video_details(video_id)

                df = df.append({'video_id':video_id,'video_title':video_title,
                                "upload_date":upload_date,"view_count":view_count,
                                "like_count":like_count,"dislike_count":dislike_count,
                                "comment_count":comment_count},ignore_index=True)
        try:
            if response['nextPageToken'] != None: #if none, it means it reached the last page and break out of it
                pageToken = "pageToken=" + response['nextPageToken']

        except:
            break


    return df

# %%
#main

#build dataframe
df2 = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","dislike_count","comment_count"]) 

df2 = get_videos(df2)

# %%
df2
# Out:
#        video_id                                        video_title  \
# 0   lxuG-gFapAo  First WWE live experience! | Brock Lesnar Retu...
# 1   kD3_ydvkdUM  New York City after COVID | Times Square | SNA...
# 2   ZCrTvf_5mRM  15 secs of beautiful places I travelled. #trav...
# 3   tHZHkRZteR0  TOP OF THE ROCK | New York City&#39;s most ama...
# 4   z8BZbwHGmzs  Liberty State Park |Riding on the streets of J...
# 5   85ojGw-nBt0  Mayweather vs Logan Paul LIVE REACTIONS.      ...
# 6   T5RNoWSyjW4  Eid Mubarak | First Eid in the US | Felt like ...
# 7   P2g42TOxVhA  Ramadan 2021 Jersey City | My first Ramadan in...
# 8   XeN2SaiHwpk  INDIA TO USA  | The NEW journey begins! |     ...
# 9   FieHb1er2Dk  Mumbai like never before! | Skateboarding tric...
# 10  _wVNe-HGApQ  Biometric appointment | Sunday in Mumbai |    ...
# 11  zLWsjjj14iE  Tamhini Ghat The most beautiful Mountain pass ...
# 12  HuK9kgD-hX4  Ajanta Ellora Caves | 2000 years old structure...
# 13  -y9luzNb6eE  Enroute Ajanta Caves via Beautiful Malshej Gha...
# 14  _y1Nv6dS3tE         M2M ferry | Gaadiyo ke saath Samandar me |
# 15  sv9SmLs9kyc           Murud-Janjira | Janjira Fort | Bike Ride
# 16  tD8LRqC_hbo   Aakhri din par maza double! Day-3 #panoramapoint
# 17  Bflw6-xQQhI  Sensational Sunrise and a lot of fun | DAY-2 #...
# 18  Tv3hRrZXrU4  Matheran Day-1 | Beautiful #hillstation in Mah...
# 19  eDwb6KzjI-M  Rajmachi fort |2 HOURS OF CHALLENGING OFFROADING|
# 20  boEhAQxtpSE  BHIVPURI MOUNTAIN CLIMB ON DUKE 390 | Most dif...
# 21  YJmS5Lh0nEA  M2M FERRY; The cheapest and the best way to tr...
# 22  BR_Mbmwo1DI  BIRTHDAY celebration! Persian darbar, Pop tate...
# 23  JXGAyDk8VD4  Daman beach | India&#39;s most beautiful beach...
# 24  _0zt17FQF1w  COASTAL ROAD (crossing border through coast)  ...
# 25  Ch4pcV7GFiM  DHABOSA WATERFALL | CITY OF WATERFALLS | MINI ...
# 26  jcn3Q6tTPjY  Lonavala after lockdown  (&quot;SHORT TREK&quo...
# 27  axB0zUW8x_A                      morbe dam first ride duke 390
# 28  KXdSzDEcbfc  Duke 390 purchased (Activa se seedha duke!) #k...
# 29  1kNn-TKXwrc                   Beautiful location near Igatpuri
# 30  QPRyAvf9sr0                                 Camping in 2020!!!
# 31  b-HXct-lkJ0                          Ramadan in lock down 2020
# 32  nz9CM1brpdk                                       Monsoon Trek
# 33  X-DXmLFtvN4                               fun during lock down
#
#    upload_date view_count like_count dislike_count comment_count
# 0   2021-09-13        189         16             0            11
# 1   2021-09-02        193         22             0             4
# 2   2021-08-20         55          6             0             0
# 3   2021-07-26        194         32             0             6
# 4   2021-07-03        191         26             0            10
# 5   2021-06-11         68          9             0             0
# 6   2021-06-09        176         23             0             7
# 7   2021-06-04        170         26             0             6
# 8   2021-05-15        420         40             0            14
# 9   2021-05-01        118         11             0             6
# 10  2021-04-27        222         25             0            12
# 11  2021-04-10         97         12             0             7
# 12  2021-03-30         93         28             0             4
# 13  2021-03-27        192         43             0            22
# 14  2021-03-06         80         18             0             0
# 15  2021-03-01        105         20             0             4
# 16  2021-02-24        128         18             0             8
# 17  2021-02-18        189         17             0             5
# 18  2021-02-16        294         10             0             4
# 19  2021-01-26        463         22             0             3
# 20  2021-01-19        726         26             3             4
# 21  2020-12-19        408         36             1             3
# 22  2020-11-22       1811         51             4            11
# 23  2020-10-04        267         37             0            10
# 24  2020-10-02        984         43             0            23
# 25  2020-09-19        207         39             0            17
# 26  2020-09-12        415         36             2            16
# 27  2020-09-10        312         52             0            21
# 28  2020-09-04        169         27             1             7
# 29  2020-08-31        143         30             0             4
# 30  2020-08-28        583        190             0            18
# 31  2020-08-14        176         21             0             4
# 32  2020-07-06        143         16             0             0
# 33  2020-06-13        241         28             0             7

# %%
df2.to_csv('youtube_videos_stats_pull.csv')
